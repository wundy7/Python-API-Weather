# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %%
#Create URL query

base_url = "http://api.openweathermap.org/data/2.5/weather?"
#api_key = config.api_key
units = "imperial"

query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6048e5ad5097da7fcd5b0035bd2593b8&units=imperial&q=

# %%
# Generate loop to go through list of cities

# Creation of lists to hold values returned from API
city_info = []
city_data = []
clouds = []
humidity = []
latitude = []
longitude = []
temp = []
wind = []

# Create loop in which to tap API and get following characteristics. Use try and else so if a city doesnt have details will skip and not error out.
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        city_id = response.get("id")
        clouds_id = response.get("clouds").get("all")
        humidity_id = response.get("main").get("humidity")
        latitude_id = response.get("coord").get("lat")
        longitude_id = response.get("coord").get("lon")
        temp_id = response.get("main")["temp"]
        wind_id = response.get("wind").get("speed")
    
        if response.get("id"):
            city_info.append(response)
            city_data.append(city)
            clouds.append(clouds_id)
            humidity.append(humidity_id)
            latitude.append(latitude_id)
            longitude.append(longitude_id)
            temp.append(temp_id)
            wind.append(wind_id)
            print(f" city is {city} and id is {city_id} and temp is {temp_id}")
        
        else:
            print(f" No details for {city}, {temp_id}")
            
    except:
        print(f"Error for {city}")  
# Print finish so know that it is done pulling details.     
print("finished")
# Out:
#  city is ushuaia and id is 3833367 and temp is 47.43
#  city is saint-philippe and id is 6138908 and temp is 81.01
#  city is esperance and id is 3573739 and temp is 82.4
#  city is provideniya and id is 4031574 and temp is 47.34
#  city is celestun and id is 3531368 and temp is 84.51
#  city is tendukheda and id is 1254751 and temp is 76.32
#  city is rikitea and id is 4030556 and temp is 73.35
#  city is lavrentiya and id is 4031637 and temp is 45.36
#  city is bluff and id is 2175403 and temp is 40.86
#  city is bredasdorp and id is 1015776 and temp is 50
#  city is cururupu and id is 3401148 and temp is 85.5
#  city is saldanha and id is 2737599 and temp is 75.6
#  city is chokurdakh and id is 2126123 and temp is 38.07
#  city is balkanabat and id is 161616 and temp is 92.34
#  city is busselton and id is 2075265 and temp is 53.1
#  city is nanortalik and id is 3421765 and temp is 44.1
#  city is tiksi and id is 2015306 and temp is 44.46
#  city is atuona and id is 4020109 and temp is 80.46
#  city is mataura and id is 6201424 and temp is 34.38
#  city is gainesville and id is 4156404 and temp is 84.88
#  city is hermanus and id is 3366880 and temp is 48.69
# Error for urumqi
#  city is muros and id is 3115824 and temp is 62.6
#  city is matagami and id is 2335713 and temp is 69.84
#  city is carpentras and id is 3028542 and temp is 68.74
#  city is usinsk and id is 863061 and temp is 53.46
# Error for attawapiskat
#  city is taoudenni and id is 2450173 and temp is 105.57
#  city is kavieng and id is 2094342 and temp is 82.53
#  city is saskylakh and id is 2017155 and temp is 53.1
#  city is lebu and id is 344979 and temp is 51.66
# Error for samusu
#  city is mecca and id is 104515 and temp is 84.15
# Error for krasnoselkup
#  city is mar del plata and id is 3863379 and temp is 53.1
#  city is te anau and id is 2181625 and temp is 26.91
#  city is albany and id is 5106834 and temp is 81.63
#  city is castro and id is 3896218 and temp is 47.52
#  city is lorengau and id is 2092164 and temp is 81.45
#  city is cape town and id is 3369157 and temp is 53.6
# Error for taolanaro
#  city is taonan and id is 2034497 and temp is 69.21
#  city is nushki and id is 1168749 and temp is 77.85
#  city is shediac and id is 6145668 and temp is 71.6
#  city is chuy and id is 3443061 and temp is 55.53
#  city is toucheng and id is 1674199 and temp is 80.6
#  city is topeka and id is 4280539 and temp is 91.4
#  city is ribeira grande and id is 3372707 and temp is 75.2
#  city is punta arenas and id is 3874787 and temp is 51.66
#  city is tuktoyaktuk and id is 6170031 and temp is 41
#  city is santa cruz and id is 5393052 and temp is 73.71
#  city is vilhena and id is 3924679 and temp is 82.4
#  city is san isidro and id is 1689639 and temp is 76.95
#  city is keuruu and id is 652977 and temp is 72.52
#  city is levashi and id is 535542 and temp is 69.8
# Error for illoqqortoormiut
#  city is cabo san lucas and id is 3985710 and temp is 83.41
#  city is puerto baquerizo moreno and id is 3652758 and temp is 75.2
#  city is muko and id is 1856456 and temp is 76.23
#  city is anadyr and id is 2127202 and temp is 37.4
#  city is fairbanks and id is 5861897 and temp is 53.53
#  city is georgetown and id is 3378644 and temp is 87.8
#  city is iqaluit and id is 5983720 and temp is 42.8
#  city is codrington and id is 2160063 and temp is 39.69
#  city is coahuayana and id is 3981460 and temp is 75.42
# Error for bengkulu
#  city is morozovsk and id is 525162 and temp is 71.28
#  city is touros and id is 3386213 and temp is 75.42
#  city is vila velha and id is 6320062 and temp is 82.4
#  city is port elizabeth and id is 4501427 and temp is 87.21
#  city is nikolskoye and id is 546105 and temp is 71.6
#  city is kasongo-lunda and id is 2315026 and temp is 79.29
#  city is port alfred and id is 964432 and temp is 55.53
#  city is husavik and id is 5961417 and temp is 78.84
#  city is paamiut and id is 3421193 and temp is 44.73
#  city is mount gambier and id is 2156643 and temp is 58.86
#  city is east london and id is 1006984 and temp is 53.6
#  city is bethel and id is 5880568 and temp is 51.8
#  city is klaksvik and id is 2618795 and temp is 50
#  city is san rafael and id is 3836669 and temp is 57.33
#  city is mocuba and id is 1024312 and temp is 72.9
#  city is upernavik and id is 3418910 and temp is 39.33
# Error for nizhneyansk
#  city is kabompo and id is 916246 and temp is 70.56
#  city is santiago del estero and id is 3835869 and temp is 64.8
#  city is valparaiso and id is 4927537 and temp is 86.77
#  city is saint george and id is 262462 and temp is 71.6
#  city is bambous virieux and id is 1106677 and temp is 68
#  city is thunder bay and id is 6166142 and temp is 71.6
#  city is hami and id is 1529484 and temp is 75.96
#  city is mmabatho and id is 975436 and temp is 62.6
#  city is alofi and id is 4036284 and temp is 62.6
#  city is semnan and id is 116402 and temp is 74.7
#  city is longyearbyen and id is 2729907 and temp is 42.8
#  city is pundaguitan and id is 1698289 and temp is 84.15
#  city is manggar and id is 1636426 and temp is 77.22
#  city is talas and id is 299900 and temp is 69.8
#  city is aklavik and id is 5882953 and temp is 42.8
#  city is gua musang and id is 1734651 and temp is 71.73
#  city is new norfolk and id is 2155415 and temp is 51.8
#  city is brenham and id is 4676206 and temp is 94.39
#  city is ganzhou and id is 1810638 and temp is 75.87
#  city is sitka and id is 4267710 and temp is 88.47
#  city is hofn and id is 2630299 and temp is 53.6
#  city is qaanaaq and id is 3831208 and temp is 36.45
#  city is tabas and id is 113659 and temp is 76.14
#  city is mangochi and id is 927246 and temp is 65.07
#  city is doha and id is 290030 and temp is 93.2
#  city is itoman and id is 1861280 and temp is 81.84
#  city is quatre cocos and id is 1106643 and temp is 68
#  city is agirish and id is 1512101 and temp is 57.33
#  city is butaritari and id is 2110227 and temp is 82.08
#  city is boende and id is 218680 and temp is 73.71
#  city is hobart and id is 2163355 and temp is 51.8
#  city is puerto ayora and id is 3652764 and temp is 80.6
#  city is aksarka and id is 1512019 and temp is 50.85
#  city is iturama and id is 3460513 and temp is 74.88
#  city is san quintin and id is 1688687 and temp is 80.6
#  city is punta and id is 1706800 and temp is 80.91
#  city is jamestown and id is 2069194 and temp is 53.37
#  city is beloha and id is 1067565 and temp is 64.98
#  city is kholmogory and id is 549748 and temp is 68
#  city is barrow and id is 3833859 and temp is 50.04
#  city is hithadhoo and id is 1282256 and temp is 83.07
#  city is rincon and id is 4218882 and temp is 92.07
#  city is kodiak and id is 4407665 and temp is 91.4
#  city is puerto el triunfo and id is 3584003 and temp is 91.4
#  city is ojinaga and id is 3994469 and temp is 91.8
#  city is pozo colorado and id is 3437443 and temp is 65.88
#  city is arlit and id is 2447513 and temp is 90.9
#  city is mahebourg and id is 934322 and temp is 68
#  city is vryburg and id is 942511 and temp is 57.96
#  city is maniitsoq and id is 3421982 and temp is 46.08
#  city is salalah and id is 286621 and temp is 78.8
#  city is pryazha and id is 504409 and temp is 73.4
#  city is victoria and id is 1733782 and temp is 79.68
#  city is avarua and id is 4035715 and temp is 69.8
#  city is cananeia and id is 3467609 and temp is 69.93
#  city is airai and id is 1651810 and temp is 63.36
#  city is thinadhoo and id is 1337610 and temp is 83.52
#  city is pangnirtung and id is 6096551 and temp is 55.4
#  city is dakar and id is 2253354 and temp is 87.8
#  city is mudanya and id is 741487 and temp is 78.21
#  city is coruripe and id is 3465329 and temp is 79.02
#  city is solnechnyy and id is 2016307 and temp is 61.65
#  city is russell and id is 3844421 and temp is 57.2
#  city is pevek and id is 2122090 and temp is 34.65
#  city is srikakulam and id is 1255647 and temp is 83.25
#  city is kapaa and id is 5848280 and temp is 80.08
#  city is moose factory and id is 6078372 and temp is 64.4
#  city is kisanga and id is 922704 and temp is 64.17
#  city is hilo and id is 5855927 and temp is 75.67
#  city is camopi and id is 3382226 and temp is 90.63
#  city is yumen and id is 1528998 and temp is 66.24
#  city is bonavista and id is 5905393 and temp is 61.65
#  city is vaini and id is 1273574 and temp is 67.5
#  city is thompson and id is 6165406 and temp is 80.6
#  city is carnarvon and id is 1014034 and temp is 40.41
#  city is yellowknife and id is 6185377 and temp is 64.4
#  city is maceio and id is 3395981 and temp is 78.8
#  city is tasiilaq and id is 3424607 and temp is 48.2
#  city is sao filipe and id is 3374210 and temp is 78.84
# Error for tsihombe
#  city is college and id is 5859699 and temp is 53.53
#  city is sao joao da barra and id is 3448903 and temp is 78.8
# Error for kapoeta
#  city is tufanganj and id is 1254131 and temp is 76.32
# Error for asau
#  city is topsham and id is 2635680 and temp is 64.4
#  city is yar-sale and id is 1486321 and temp is 51.75
#  city is ystad and id is 2662149 and temp is 72.45
#  city is esqueda and id is 4006532 and temp is 79.38
#  city is murupara and id is 2186338 and temp is 34.74
#  city is tamandare and id is 3661980 and temp is 83.52
#  city is dunedin and id is 2191562 and temp is 35.1
#  city is tautira and id is 4033557 and temp is 80.6
#  city is camapua and id is 3468020 and temp is 65.43
#  city is burnie and id is 2173125 and temp is 54.9
#  city is piet retief and id is 965241 and temp is 55.35
#  city is orlik and id is 1496073 and temp is 47.52
#  city is san luis and id is 3837056 and temp is 63.81
#  city is piterka and id is 509269 and temp is 65.16
#  city is dikson and id is 1507390 and temp is 50.4
#  city is tilichiki and id is 2120591 and temp is 51.57
#  city is bar harbor and id is 4957320 and temp is 70.47
#  city is labuhan and id is 1641899 and temp is 72.09
#  city is nosy varika and id is 1058080 and temp is 67.95
#  city is berlevag and id is 780687 and temp is 48.2
#  city is norman wells and id is 6089245 and temp is 50
# Error for mys shmidta
#  city is balabac and id is 1728675 and temp is 83.88
# Error for belushya guba
#  city is grand-santi and id is 3381538 and temp is 89.1
#  city is itarema and id is 3393692 and temp is 89.19
#  city is arkhangelskoye and id is 468671 and temp is 61.83
#  city is hasaki and id is 2112802 and temp is 78.35
#  city is cherskiy and id is 2126199 and temp is 37.08
# Error for tumannyy
#  city is honiara and id is 2108502 and temp is 75.2
#  city is tarko-sale and id is 1490085 and temp is 48.6
#  city is axim and id is 2303611 and temp is 78.12
# Error for tukrah
#  city is mana and id is 789988 and temp is 72.39
#  city is umm lajj and id is 100926 and temp is 84.78
#  city is cabedelo and id is 3404558 and temp is 73.4
#  city is petropavlovsk-kamchatskiy and id is 2122104 and temp is 44.6
#  city is benguela and id is 3351663 and temp is 68.76
#  city is geraldton and id is 5960603 and temp is 77
#  city is abu dhabi and id is 292968 and temp is 103.24
#  city is fortuna and id is 2517679 and temp is 85.1
#  city is laguna and id is 4013704 and temp is 89.6
#  city is margate and id is 2158744 and temp is 51.8
#  city is sechura and id is 3691954 and temp is 71.82
#  city is luderitz and id is 3355672 and temp is 55.71
#  city is sidney and id is 5677735 and temp is 91.4
#  city is flin flon and id is 5954718 and temp is 86
#  city is vardo and id is 4372777 and temp is 87.8
#  city is tooele and id is 5783695 and temp is 90.03
#  city is mustasaari and id is 651301 and temp is 69.8
# Error for saleaula
#  city is bay city and id is 4985180 and temp is 83.82
#  city is fort morgan and id is 5577158 and temp is 87.19
#  city is faanui and id is 4034551 and temp is 82.35
#  city is mbaiki and id is 2384770 and temp is 77.49
#  city is golden and id is 5962582 and temp is 80.6
#  city is riyadh and id is 108410 and temp is 96.8
#  city is khatanga and id is 2022572 and temp is 57.6
#  city is panaba and id is 3521972 and temp is 87.93
#  city is carndonagh and id is 2965761 and temp is 59
#  city is richards bay and id is 962367 and temp is 55.98
#  city is fort nelson and id is 5955902 and temp is 73.4
#  city is sambava and id is 1056899 and temp is 73.8
#  city is rio tercero and id is 3838793 and temp is 57.06
#  city is lagoa and id is 2267254 and temp is 84.2
#  city is athlone and id is 2966839 and temp is 59.22
#  city is severo-kurilsk and id is 2121385 and temp is 49.5
#  city is tamiahua and id is 3516376 and temp is 84.69
#  city is torbay and id is 6167817 and temp is 64.4
# Error for toamua
# Error for tabiauea
#  city is cap malheureux and id is 934649 and temp is 68
#  city is bandarbeyla and id is 64814 and temp is 80.1
# Error for wahran
#  city is roald and id is 3141667 and temp is 61.47
#  city is makinsk and id is 1521230 and temp is 65.43
#  city is miyang and id is 1800430 and temp is 61.65
#  city is praia da vitoria and id is 3372760 and temp is 77
#  city is coolum beach and id is 2170581 and temp is 60.75
#  city is biltine and id is 244878 and temp is 77.85
#  city is tiruvallur and id is 1254331 and temp is 80.6
#  city is thohoyandou and id is 949224 and temp is 57.51
#  city is paveh and id is 121240 and temp is 69.48
#  city is port augusta and id is 2063056 and temp is 59
#  city is sorong and id is 1626542 and temp is 79.11
#  city is jiaohe and id is 2036536 and temp is 63.36
#  city is saint-augustin and id is 3031582 and temp is 68
# Error for palabuhanratu
#  city is noshiro and id is 2128867 and temp is 75.42
#  city is northam and id is 2641434 and temp is 63.16
#  city is vagur and id is 2610806 and temp is 53.28
# Error for bargal
#  city is minudasht and id is 132938 and temp is 79.47
#  city is arraial do cabo and id is 3471451 and temp is 81.54
#  city is bereda and id is 3105522 and temp is 64.4
#  city is hailar and id is 2037078 and temp is 55.35
# Error for barentsburg
#  city is saint anthony and id is 5606187 and temp is 83.12
# Error for olafsvik
#  city is sorland and id is 3137469 and temp is 55.4
#  city is catuday and id is 1717787 and temp is 76.77
#  city is la ronge and id is 6050066 and temp is 80.6
#  city is nishihara and id is 1850144 and temp is 80.83
#  city is hualmay and id is 3939761 and temp is 68.13
#  city is san patricio and id is 3437029 and temp is 58.41
#  city is calabozo and id is 3647444 and temp is 83.61
#  city is vao and id is 588365 and temp is 75.96
#  city is mareeba and id is 2158767 and temp is 60.8
#  city is flinders and id is 6255012 and temp is 46.4
# Error for tabulbah
# Error for grand river south east
#  city is ugoofaaru and id is 1337619 and temp is 84.6
#  city is pingliang and id is 1798760 and temp is 67.41
#  city is mabaruma and id is 3377301 and temp is 85.77
#  city is moranbah and id is 6533368 and temp is 40.05
#  city is coihaique and id is 3894426 and temp is 47.57
#  city is ewa beach and id is 5855051 and temp is 81.03
#  city is verkhoyansk and id is 2013465 and temp is 46.62
#  city is dong hoi and id is 1582886 and temp is 78.66
#  city is progreso and id is 3440963 and temp is 51.8
#  city is daru and id is 2409663 and temp is 72.36
#  city is qorveh and id is 119161 and temp is 74.43
#  city is mudanjiang and id is 2035715 and temp is 63.9
#  city is xam nua and id is 1652203 and temp is 68.67
#  city is pangody and id is 1495626 and temp is 51.39
#  city is tuatapere and id is 2180815 and temp is 43.2
#  city is guerrero negro and id is 4021858 and temp is 89.1
#  city is angoche and id is 1052944 and temp is 76.41
#  city is san carlos de bariloche and id is 7647007 and temp is 42.8
#  city is qaqortoq and id is 3420846 and temp is 60.8
#  city is mount isa and id is 2065594 and temp is 37.4
#  city is santa maria and id is 3450083 and temp is 51.8
#  city is itapemirim and id is 3460738 and temp is 78.3
#  city is bubaque and id is 2374583 and temp is 75.2
#  city is lompoc and id is 5367788 and temp is 79.47
#  city is olot and id is 1217907 and temp is 82.53
#  city is arys and id is 1526168 and temp is 78.8
#  city is georgiyevka and id is 565857 and temp is 63.36
#  city is eregli and id is 315498 and temp is 69.12
#  city is hammerfest and id is 779683 and temp is 51.13
#  city is louth and id is 2643553 and temp is 61.93
#  city is ust-tsilma and id is 477940 and temp is 56.88
#  city is obo and id is 236950 and temp is 73.98
#  city is athabasca and id is 5887916 and temp is 80.46
#  city is lodja and id is 211647 and temp is 78.12
#  city is vestmanna and id is 2610343 and temp is 50
#  city is serenje and id is 898912 and temp is 66.69
#  city is west bay and id is 2654726 and temp is 64.4
#  city is sabha and id is 2212775 and temp is 99.63
#  city is ahipara and id is 2194098 and temp is 49.05
#  city is saint-pierre and id is 2995603 and temp is 62.98
#  city is santa isabel do rio negro and id is 3662489 and temp is 87.75
#  city is madarounfa and id is 2441526 and temp is 78.8
#  city is chara and id is 262462 and temp is 71.6
#  city is kavaratti and id is 1267390 and temp is 83.34
#  city is leningradskiy and id is 2123814 and temp is 33.84
#  city is lodhikheda and id is 1264860 and temp is 80.6
#  city is belyy yar and id is 1510377 and temp is 59
#  city is miles city and id is 5666176 and temp is 96.8
#  city is kjollefjord and id is 779261 and temp is 48.2
#  city is lanzhou and id is 1804430 and temp is 62.6
# Error for bur gabo
#  city is tevaitoa and id is 4033375 and temp is 81.9
#  city is lakes entrance and id is 2160735 and temp is 46.44
#  city is talnakh and id is 1490256 and temp is 52.11
#  city is waddan and id is 2209055 and temp is 94.95
# Error for maloshuyka
#  city is baker city and id is 5712169 and temp is 90.23
#  city is aranos and id is 3358666 and temp is 62.46
#  city is taloqan and id is 1123004 and temp is 63.36
#  city is brae and id is 2654970 and temp is 57.2
#  city is oneida and id is 4898722 and temp is 89.1
#  city is katol and id is 1267461 and temp is 80.6
#  city is saint-francois and id is 2980080 and temp is 68
#  city is mujiayingzi and id is 2035707 and temp is 60.12
#  city is aykhal and id is 2027296 and temp is 49.41
#  city is krivosheino and id is 1501795 and temp is 64.17
#  city is vung tau and id is 1562414 and temp is 77
#  city is batagay and id is 2027044 and temp is 45.54
#  city is narsaq and id is 3421719 and temp is 60.8
#  city is lakselv and id is 779082 and temp is 53.85
#  city is port lincoln and id is 2063036 and temp is 59.22
#  city is ilulissat and id is 3423146 and temp is 39.2
#  city is the pas and id is 6164499 and temp is 86
#  city is atasu and id is 1526041 and temp is 73.62
#  city is cervo and id is 3469169 and temp is 67.5
#  city is pimentel and id is 3389609 and temp is 86.04
#  city is dwarka and id is 1273294 and temp is 81.63
#  city is puerto escondido and id is 3520994 and temp is 86
#  city is kerewan and id is 2412992 and temp is 78.8
#  city is sovetskiy and id is 490040 and temp is 54.72
# Error for kuche
#  city is jalu and id is 86049 and temp is 103.5
#  city is kindu and id is 212902 and temp is 80.37
#  city is oranjestad and id is 3577154 and temp is 89.6
#  city is ust-maya and id is 2013918 and temp is 52.92
#  city is comodoro rivadavia and id is 3860443 and temp is 51.8
#  city is cidreira and id is 3466165 and temp is 53.55
#  city is mantua and id is 3174050 and temp is 70.21
#  city is catia la mar and id is 3646190 and temp is 86
#  city is colares and id is 2269142 and temp is 71.13
#  city is taga and id is 1851279 and temp is 82.4
#  city is erbach and id is 2929804 and temp is 69.22
# Error for felidhoo
#  city is seoni and id is 1256826 and temp is 75.42
#  city is beidao and id is 1816751 and temp is 68.13
#  city is ambilobe and id is 1082243 and temp is 75.24
#  city is kralendijk and id is 3513563 and temp is 87.8
#  city is outjo and id is 3353715 and temp is 58.23
#  city is arteaga and id is 4018127 and temp is 82.4
#  city is griffith and id is 2164422 and temp is 42.66
#  city is mnogovershinnyy and id is 2019935 and temp is 56.43
#  city is burgeo and id is 5911440 and temp is 59.4
#  city is bayan and id is 2030079 and temp is 55.89
#  city is isangel and id is 2136825 and temp is 71.91
#  city is souillac and id is 3026644 and temp is 68.81
#  city is necochea and id is 3430443 and temp is 50.67
#  city is kabare and id is 216281 and temp is 63.09
#  city is oparino and id is 515175 and temp is 56.25
#  city is milkovo and id is 727030 and temp is 79.83
#  city is kulhudhuffushi and id is 1337613 and temp is 84.6
#  city is tecpan and id is 3588476 and temp is 75.2
#  city is demba and id is 217389 and temp is 81.18
#  city is port macquarie and id is 2152659 and temp is 41
#  city is beringovskiy and id is 2126710 and temp is 44.82
#  city is roebourne and id is 2062276 and temp is 60.03
#  city is kankakee and id is 4898182 and temp is 88.23
# Error for sentyabrskiy
#  city is matay and id is 352628 and temp is 87.57
#  city is deputatskiy and id is 2028164 and temp is 42.3
#  city is gao and id is 2457163 and temp is 84.96
#  city is arklow and id is 2966883 and temp is 60.8
#  city is potrerillos arriba and id is 3702548 and temp is 84.2
#  city is aksha and id is 2028028 and temp is 47.79
#  city is sur and id is 286245 and temp is 80.91
#  city is avera and id is 4231997 and temp is 88.48
#  city is savannah bight and id is 3601402 and temp is 83.43
#  city is port hardy and id is 6111862 and temp is 64.4
#  city is boyolangu and id is 1648082 and temp is 70.47
#  city is tselinnoye and id is 689307 and temp is 78.75
#  city is road town and id is 3577430 and temp is 87.8
#  city is zhenjiang and id is 1784642 and temp is 82.4
#  city is podporozhye and id is 508034 and temp is 71.82
#  city is sept-iles and id is 6144312 and temp is 62.6
#  city is pontianak and id is 1630789 and temp is 79.38
#  city is shitanjing and id is 1794971 and temp is 65.7
#  city is tromso and id is 3133895 and temp is 55.4
#  city is bonnyville and id is 5905616 and temp is 80.6
#  city is port hedland and id is 2063042 and temp is 55.4
#  city is mayo and id is 6068416 and temp is 50
#  city is kununurra and id is 2068110 and temp is 48.2
#  city is tunceli and id is 298846 and temp is 76.03
#  city is nouadhibou and id is 2377457 and temp is 77
#  city is yinchuan and id is 1786657 and temp is 65.16
#  city is curvelo and id is 3464891 and temp is 84.06
#  city is atherton and id is 2656847 and temp is 61.68
#  city is monte patria and id is 3879429 and temp is 64.44
#  city is kulu and id is 206362 and temp is 77.04
#  city is morondava and id is 1058381 and temp is 72.72
# Error for senmonorom
#  city is puerto colombia and id is 3671497 and temp is 91.4
#  city is kahului and id is 5847411 and temp is 78.8
#  city is ionia and id is 4997191 and temp is 80.56
#  city is changji and id is 1790885 and temp is 81.45
#  city is palu and id is 1633034 and temp is 67.5
#  city is surt and id is 2210554 and temp is 80.64
#  city is umm kaddadah and id is 364933 and temp is 79.47
#  city is calama and id is 3897347 and temp is 75.2
#  city is srednekolymsk and id is 2121025 and temp is 43.38
#  city is kaitangata and id is 2208248 and temp is 39.96
#  city is jussara and id is 3459531 and temp is 95.94
#  city is kawalu and id is 1640902 and temp is 65.88
#  city is qasigiannguit and id is 3420768 and temp is 39.2
#  city is portland and id is 5746545 and temp is 78.76
# Error for satitoa
#  city is langres and id is 3007680 and temp is 68
#  city is montepuez and id is 1037125 and temp is 70.65
#  city is bocas del toro and id is 3713959 and temp is 80.19
# Error for of
# Error for vaitupu
#  city is kiyasovo and id is 547927 and temp is 58.23
#  city is tessalit and id is 2449893 and temp is 97.02
#  city is kirakira and id is 2178753 and temp is 78.93
#  city is canchungo and id is 2373951 and temp is 77.05
#  city is seydi and id is 2448024 and temp is 73.08
#  city is ocosingo and id is 3816237 and temp is 68.4
#  city is kenai and id is 5866063 and temp is 59.88
#  city is ust-nera and id is 2120048 and temp is 36.36
#  city is caravelas and id is 3466980 and temp is 77.13
#  city is thanh hoa and id is 1574023 and temp is 75.78
#  city is champasak and id is 1657819 and temp is 72.72
# Error for geresk
# Error for tabialan
#  city is spruce grove and id is 6154383 and temp is 84.2
# Error for temaraia
#  city is porto novo and id is 6322184 and temp is 80.6
#  city is marystown and id is 6067472 and temp is 66.51
#  city is banita and id is 685450 and temp is 63.81
#  city is montrose and id is 2157161 and temp is 50.85
#  city is ouadda and id is 236901 and temp is 82.08
#  city is totolac and id is 3815419 and temp is 71.6
#  city is nouakchott and id is 2377450 and temp is 77.94
#  city is kabelvag and id is 3150639 and temp is 57.22
# Error for mafinga
#  city is preobrazheniye and id is 2017658 and temp is 57.96
# Error for zachagansk
#  city is roros and id is 3141332 and temp is 62.6
#  city is horta and id is 3128760 and temp is 73.44
# Error for mooi river
# Error for ust-kamchatsk
#  city is lope de vega and id is 1705575 and temp is 82.98
#  city is jumla and id is 1283285 and temp is 37.08
#  city is okha and id is 2122614 and temp is 52.65
#  city is ahuimanu and id is 5856516 and temp is 80.2
#  city is ponta delgada and id is 3372783 and temp is 71.6
#  city is evensk and id is 2125693 and temp is 55.08
#  city is mathbaria and id is 1185239 and temp is 81.63
#  city is saint-joseph and id is 3037456 and temp is 70.36
#  city is malanje and id is 2239862 and temp is 71.82
#  city is noumea and id is 2139521 and temp is 69.8
#  city is luganville and id is 2136150 and temp is 75.96
#  city is kidal and id is 2455290 and temp is 91.53
#  city is hue and id is 1580240 and temp is 78.8
#  city is omsukchan and id is 2122493 and temp is 45.36
#  city is muhlhausen and id is 2867996 and temp is 75.2
#  city is henties bay and id is 3356832 and temp is 56.79
#  city is tsabong and id is 932987 and temp is 64.53
#  city is ponta do sol and id is 3453439 and temp is 70.65
#  city is ler and id is 3146125 and temp is 60.58
#  city is hambantota and id is 1244926 and temp is 79.11
#  city is dingle and id is 1714733 and temp is 77.13
#  city is okhotsk and id is 2122605 and temp is 54.36
#  city is darhan and id is 2031964 and temp is 59.4
#  city is koslan and id is 544084 and temp is 61.83
#  city is dudinka and id is 1507116 and temp is 54.99
#  city is nehe and id is 2035610 and temp is 63.54
#  city is hervey bay and id is 2146219 and temp is 60.75
#  city is koroni and id is 259265 and temp is 77
#  city is los llanos de aridane and id is 2514651 and temp is 77
#  city is bumbuna and id is 2409829 and temp is 73.98
#  city is tefe and id is 3661944 and temp is 87.8
#  city is xinzhi and id is 1670479 and temp is 78.55
#  city is romny and id is 695464 and temp is 66.06
#  city is manitouwadge and id is 6065253 and temp is 71.6
#  city is vestmannaeyjar and id is 3412093 and temp is 53.6
#  city is torrington and id is 5841207 and temp is 90.39
#  city is altay and id is 1529651 and temp is 51.12
#  city is susangerd and id is 137268 and temp is 104
#  city is nome and id is 4732862 and temp is 89.2
#  city is yokadouma and id is 2220853 and temp is 75.33
# Error for mananara
#  city is funadhoo and id is 1337620 and temp is 84.6
#  city is edmundston and id is 6545023 and temp is 72.77
#  city is islamkot and id is 1176608 and temp is 81.45
#  city is warwick and id is 5225507 and temp is 86.45
#  city is paris and id is 2988507 and temp is 63.27
#  city is sharya and id is 495619 and temp is 56.7
#  city is tocopilla and id is 3869716 and temp is 62.73
#  city is khandyga and id is 2022773 and temp is 54.45
#  city is barranca and id is 3946820 and temp is 61.92
#  city is ous and id is 1495812 and temp is 57.87
#  city is buala and id is 2109528 and temp is 77.49
#  city is arnedo and id is 6359008 and temp is 68
#  city is the valley and id is 3573374 and temp is 86.94
#  city is ugento and id is 2522833 and temp is 82.4
#  city is zhaodong and id is 2033168 and temp is 66.2
#  city is boden and id is 606531 and temp is 69.8
#  city is kieta and id is 2094027 and temp is 76.14
# Error for chikoy
#  city is kagoro and id is 2335614 and temp is 69.84
#  city is port moresby and id is 2088122 and temp is 73.4
#  city is havoysund and id is 779622 and temp is 50
#  city is novoselytsya and id is 699285 and temp is 68
#  city is vila franca do campo and id is 3372472 and temp is 71.6
#  city is troitskoye and id is 1489209 and temp is 58.95
#  city is dalbandin and id is 1180729 and temp is 81.18
#  city is chunoyar and id is 1507638 and temp is 57.33
# Error for korla
#  city is nador and id is 2541479 and temp is 82.4
#  city is isoka and id is 916668 and temp is 69.39
#  city is bambanglipuro and id is 1650434 and temp is 71.46
#  city is aksu and id is 1524298 and temp is 68
# Error for bokspits
#  city is abalak and id is 2448245 and temp is 84.42
#  city is ulladulla and id is 2145554 and temp is 46.4
#  city is kigorobya and id is 231426 and temp is 78.48
#  city is abay and id is 1526970 and temp is 57.2
#  city is kampot and id is 1831112 and temp is 75.6
#  city is bilibino and id is 2126682 and temp is 34.92
#  city is san lorenzo and id is 3601977 and temp is 92.25
#  city is panzhihua and id is 6929460 and temp is 64.35
#  city is yulara and id is 6355222 and temp is 37.4
#  city is victor harbor and id is 2059470 and temp is 59
#  city is adrar and id is 2508813 and temp is 102.2
#  city is karratha and id is 6620339 and temp is 60.03
#  city is langham and id is 6049403 and temp is 82.4
#  city is buin and id is 3897774 and temp is 77
#  city is champerico and id is 3530097 and temp is 86
#  city is oyotun and id is 3694197 and temp is 73.4
# Error for meyungs
#  city is bozoum and id is 2387546 and temp is 75.96
#  city is beyneu and id is 610298 and temp is 70.38
#  city is clyde river and id is 5924351 and temp is 41
# Error for kazalinsk
#  city is trairi and id is 3386177 and temp is 79.02
#  city is penzance and id is 2640377 and temp is 58.86
#  city is nelson bay and id is 2155562 and temp is 37.4
#  city is kungurtug and id is 1501377 and temp is 45.45
#  city is yueyang and id is 1927639 and temp is 79.74
#  city is teruel and id is 3108126 and temp is 71.6
#  city is jishou and id is 1805270 and temp is 73.98
#  city is amapa and id is 3603330 and temp is 89.6
#  city is wawa and id is 2319078 and temp is 74.25
#  city is zhongshu and id is 1784310 and temp is 60.12
#  city is nacala and id is 1035025 and temp is 75.24
#  city is san cristobal and id is 3652462 and temp is 62.6
#  city is tigil and id is 2120612 and temp is 50.4
#  city is bagacay and id is 1729278 and temp is 83.34
#  city is mirador and id is 3394813 and temp is 94.32
#  city is zhigalovo and id is 2012532 and temp is 55.26
#  city is sumenep and id is 1626099 and temp is 80.55
#  city is honningsvag and id is 779554 and temp is 50.49
#  city is ha tinh and id is 1581047 and temp is 83.16
#  city is lingao and id is 1803560 and temp is 76.86
#  city is takoradi and id is 2294915 and temp is 77.85
#  city is itauna and id is 3471715 and temp is 81.5
#  city is shelburne and id is 6145890 and temp is 82.94
# Error for opobo
# Error for amderma
#  city is loanda and id is 3458479 and temp is 66.06
#  city is ishigaki and id is 1861416 and temp is 85.05
#  city is mokhsogollokh and id is 2019867 and temp is 57.42
#  city is pacific grove and id is 5380437 and temp is 76.32
#  city is stilfontein and id is 952192 and temp is 56.7
#  city is matamoros and id is 3523466 and temp is 94.86
#  city is arequipa and id is 3947322 and temp is 73.4
#  city is tura and id is 1254046 and temp is 80.28
#  city is mitchell and id is 5229794 and temp is 87.8
#  city is nuuk and id is 3421319 and temp is 57.2
# Error for toliary
#  city is anshun and id is 1817968 and temp is 65.97
# Error for acarau
# Error for tucuma
# Error for perbaungan
#  city is qujing and id is 1797318 and temp is 57.78
#  city is faya and id is 110690 and temp is 73.4
#  city is manoel urbano and id is 3663495 and temp is 88.2
#  city is juba and id is 587450 and temp is 75.2
#  city is los aquijes and id is 3935969 and temp is 66.2
#  city is shimoda and id is 1852357 and temp is 80.6
#  city is chimbote and id is 3698304 and temp is 65.97
#  city is pramanta and id is 254746 and temp is 71.6
#  city is la palma and id is 3687505 and temp is 84.06
#  city is najran and id is 103630 and temp is 93.2
#  city is itupiranga and id is 3397851 and temp is 96.8
#  city is maun and id is 933366 and temp is 75.33
#  city is decatur and id is 4617650 and temp is 81.3
#  city is tinskoy and id is 1489571 and temp is 61.56
#  city is constitucion and id is 4011743 and temp is 75.2
#  city is alindao and id is 240999 and temp is 80.82
#  city is pulandian and id is 1798490 and temp is 78.8
#  city is campbell river and id is 5914132 and temp is 81.16
#  city is druzhinino and id is 564878 and temp is 50.94
#  city is kruisfontein and id is 986717 and temp is 55.89
#  city is batemans bay and id is 2176639 and temp is 40.5
#  city is dongsheng and id is 1788268 and temp is 81.54
#  city is taunggyi and id is 1293960 and temp is 67.5
#  city is ouesso and id is 2255564 and temp is 74.16
#  city is corinth and id is 259289 and temp is 82.4
#  city is boa vista and id is 3664980 and temp is 91.4
#  city is mogadishu and id is 53654 and temp is 77.58
#  city is zyryanskoye and id is 1484892 and temp is 57.33
#  city is linhares and id is 3458498 and temp is 79.92
#  city is tadine and id is 2138285 and temp is 70.65
#  city is kaka and id is 161901 and temp is 64.8
# Error for umzimvubu
#  city is lethem and id is 3379316 and temp is 92.88
#  city is namatanai and id is 2090021 and temp is 80.91
#  city is meulaboh and id is 1214488 and temp is 79.38
#  city is liseleje and id is 2617538 and temp is 72.81
#  city is aalten and id is 2760123 and temp is 67.41
#  city is pedernales and id is 3653307 and temp is 85.14
#  city is krasnovishersk and id is 542184 and temp is 51.66
# Error for labutta
# Error for ketchenery
#  city is mandalgovi and id is 2030065 and temp is 61.92
#  city is manoharpur and id is 1263651 and temp is 76.05
#  city is pasighat and id is 1260206 and temp is 71.1
#  city is myanaung and id is 1308204 and temp is 76.68
#  city is stephenville and id is 4734350 and temp is 93.6
#  city is whitehorse and id is 6180550 and temp is 53.6
#  city is palembang and id is 1633070 and temp is 78.12
#  city is artigas and id is 3443758 and temp is 53.19
#  city is palmer and id is 5871146 and temp is 57.76
#  city is rognan and id is 3141548 and temp is 59
#  city is manicore and id is 3663503 and temp is 78.8
# Error for mrirt
# Error for karaul
#  city is selje and id is 3139914 and temp is 60.82
#  city is biarritz and id is 3032797 and temp is 67.41
#  city is tiznit and id is 2527089 and temp is 74.97
#  city is merauke and id is 2082539 and temp is 73.71
#  city is sibi and id is 1164896 and temp is 94.68
#  city is vanimo and id is 2084442 and temp is 83.7
#  city is albanel and id is 5883074 and temp is 80.6
#  city is amudat and id is 235191 and temp is 60.21
#  city is butte and id is 5642934 and temp is 86
#  city is taicheng and id is 1793700 and temp is 80.1
#  city is tongchuan and id is 7064006 and temp is 80.6
# Error for dzhusaly
#  city is voh and id is 2137748 and temp is 69.57
#  city is rosarito and id is 3676604 and temp is 86.88
#  city is poum and id is 787487 and temp is 65.88
#  city is castro alves and id is 3466703 and temp is 83.25
#  city is kudahuvadhoo and id is 1337607 and temp is 84.33
#  city is waingapu and id is 1622318 and temp is 70.02
#  city is kozluk and id is 306041 and temp is 82.4
#  city is morristown and id is 4642938 and temp is 80.6
#  city is lalmohan and id is 1185251 and temp is 82.44
#  city is warrington and id is 2634739 and temp is 62.69
#  city is hamilton and id is 3573197 and temp is 84.2
#  city is broken hill and id is 2173911 and temp is 49.32
#  city is baherden and id is 162158 and temp is 83.88
#  city is handlova and id is 3060139 and temp is 80.17
#  city is pilar and id is 3427208 and temp is 52.97
#  city is okmulgee and id is 4544383 and temp is 89.6
#  city is nileshwar and id is 1261394 and temp is 74.25
#  city is hobyo and id is 57000 and temp is 77.76
#  city is zhanaozen and id is 607610 and temp is 83.61
#  city is hay river and id is 5972762 and temp is 68
#  city is padang and id is 1633419 and temp is 82.62
#  city is mudgee and id is 2156404 and temp is 29.7
#  city is trapani and id is 6542155 and temp is 82.4
#  city is lubao and id is 1705441 and temp is 77.65
#  city is thyboron and id is 2611738 and temp is 67.32
#  city is asyut and id is 359783 and temp is 89.6
#  city is zlobin and id is 3191648 and temp is 80.6
# Error for promysla
#  city is cortez and id is 5418104 and temp is 87.8
#  city is tirano and id is 3165647 and temp is 55.4
#  city is nova vodolaha and id is 699777 and temp is 66.2
#  city is poso and id is 1630723 and temp is 77.85
#  city is salina cruz and id is 3520064 and temp is 90
#  city is kilgore and id is 4703199 and temp is 92.8
#  city is tacuarembo and id is 3440034 and temp is 54.81
#  city is broome and id is 2656067 and temp is 56.48
#  city is lipari and id is 2524379 and temp is 84.2
#  city is chenzhou and id is 1815059 and temp is 73.98
#  city is bagaha and id is 1277939 and temp is 81.09
#  city is marienburg and id is 2803461 and temp is 71.67
#  city is turan and id is 1488950 and temp is 49.14
# Error for galiwinku
#  city is primero de enero and id is 3543498 and temp is 89.6
# Error for marcona
#  city is turukhansk and id is 1488903 and temp is 56.07
#  city is bila krynytsya and id is 712656 and temp is 69.8
# Error for kachikau
#  city is olinda and id is 3650121 and temp is 80.6
#  city is benghazi and id is 88319 and temp is 84.2
#  city is mitsamiouli and id is 921786 and temp is 75.2
#  city is alta floresta and id is 6316343 and temp is 98.73
#  city is waikuku and id is 2180219 and temp is 48.2
#  city is rani and id is 1283582 and temp is 80.73
#  city is pemba and id is 1028918 and temp is 73.4
#  city is cayenne and id is 3382160 and temp is 87.8
#  city is ntcheu and id is 924492 and temp is 61.47
#  city is ketchikan and id is 5554428 and temp is 60.8
#  city is hovd and id is 7626384 and temp is 60.66
#  city is constantine and id is 2501152 and temp is 82.4
#  city is lasa and id is 146639 and temp is 81.61
#  city is scarborough and id is 2638419 and temp is 63.25
#  city is sobolevo and id is 525426 and temp is 66.6
#  city is secovce and id is 723637 and temp is 76.96
#  city is bangil and id is 1650319 and temp is 77
#  city is santa marta and id is 3668605 and temp is 91.4
#  city is bone and id is 2057087 and temp is 76.23
#  city is francisco sa and id is 3462975 and temp is 81
#  city is bata and id is 2310046 and temp is 78.8
#  city is povazska bystrica and id is 3058060 and temp is 81.79
#  city is tomatlan and id is 3981391 and temp is 86.85
#  city is patna and id is 1260086 and temp is 86
#  city is tirat karmel and id is 293308 and temp is 84.2
#  city is adre and id is 245669 and temp is 77.22
#  city is alice springs and id is 2077895 and temp is 55.4
# Error for ngukurr
#  city is khuzhir and id is 2022143 and temp is 53.82
#  city is katangli and id is 2122783 and temp is 50.4
#  city is saint-denis and id is 2980916 and temp is 62.15
#  city is seybaplaya and id is 3516685 and temp is 87.8
#  city is gamba and id is 1281256 and temp is 36.9
# Error for bolungarvik
#  city is acapulco and id is 3533462 and temp is 87.8
#  city is atambua and id is 1651103 and temp is 72.72
#  city is sanghar and id is 1176515 and temp is 89.46
#  city is bathsheba and id is 3374083 and temp is 87.8
#  city is almaznyy and id is 582447 and temp is 72.18
#  city is albury and id is 2178174 and temp is 33.8
#  city is kalofer and id is 730744 and temp is 77
#  city is taitung and id is 1668295 and temp is 76.14
#  city is gouyave and id is 3580279 and temp is 86
#  city is suntar and id is 2015913 and temp is 50.94
#  city is komsomolskiy and id is 1486910 and temp is 50.4
#  city is salur and id is 1257587 and temp is 75.96
#  city is katsuura and id is 1865309 and temp is 79.83
#  city is labuan and id is 1733782 and temp is 78.8
#  city is gobo and id is 1863614 and temp is 80.6
#  city is ancud and id is 3899695 and temp is 48.78
#  city is abha and id is 110690 and temp is 73.4
# finished

# %%
# Create new dictionary from api 
weather_dict = {
    "City": city_data,
    "Cloudiness":clouds,
    "Humidity": humidity,
    "Latitude": latitude,
    "Longitude": longitude,
    "Temperature": temp,
    "Wind Speed": wind
}

#Count number of cities to ensure have more than 500
len(weather_dict["City"])
# Out:
# 712

# %%
# Generate new DataFrame with details from openweathermap
weather_data = pd.DataFrame(weather_dict)
weather_data.head()

# Output File (CSV)
weather_data.to_csv("cities_data.csv", encoding='utf-8', index=False)

# %%
#Generate Scatter Plot
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], facecolors="lightskyblue", edgecolors='black', alpha = 1)

# create chart title, labels, legends, note on driver count, and formatting
plt.title("August 9th: Temperature (F) vs Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")


plt.savefig("Temp_vs_Lat.png")

plt.show()

# %%
# Generate Scatter Plot
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors="lightskyblue", edgecolors='black', alpha = 1)

# create chart title, labels, legends, note on driver count, and formatting
plt.title("August 9th: Humidity vs Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")

plt.savefig("Hum_vs_Lat.png")

plt.show()

# %%
#Generate Scatter Plot
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="lightskyblue", edgecolors='black', alpha = 1)

# create chart title, labels, legends, note on driver count, and formatting
plt.title("August 9th: Cloudiness vs Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

plt.savefig("Cld_vs_Lat.png")

plt.show()

# %%
# Generate Scatter Plot
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="lightskyblue", edgecolors='black', alpha = 1)

# create chart title, labels, legends, note on driver count, and formatting
plt.title("August 9th: Wind Speed vs Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

plt.savefig("Cld_vs_Lat.png")

plt.show()

# %%
# Observable Trends

    #1) One assumption going in as that I assumed temperatures would be hottest at 0 degrees latitude. However,
    #   when analyzing the data it appears the hottest latitudes appear closer to the 20 degrees to 40 degrees.
    #   I would be curious if this trend is consistent throughout the year. 
    
    #2) Another trend is that once one gets 20 degrees +/- from the equator temperatures begin to drop. 
    #3) When analyzing wind speed it is hard to determine trends as the wind speed is pretty consistent throughout the 
    #   latitdudes. There do appear to be a few locations with windsppeds greater than 15 mph and more locations appear
    #   once one begins to get 20 degrees +/- from the equator. However, I would want to further investigate the data points
    #   to see if a storm was occuring at the time the data is run. Also, I would want to see how the data looks over a time
    #   period. Perhaps, looking over a period of time may show more consistent wind conditions for a specific location,
    #   thus allowing one to compare wind speed vs. latitude.
